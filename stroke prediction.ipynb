# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Hello\Desktop\healthcare-dataset-stroke-data.csv")

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data.bmi
# Out:
# 0       36.6
# 1        NaN
# 2       32.5
# 3       34.4
# 4       24.0
#         ...
# 5105     NaN
# 5106    40.0
# 5107    30.6
# 5108    25.6
# 5109    26.2
# Name: bmi, Length: 5110, dtype: float64

# %%
data['bmi'].fillna(data['bmi'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data.bmi
# Out:
# 0       36.600000
# 1       28.893237
# 2       32.500000
# 3       34.400000
# 4       24.000000
#           ...
# 5105    28.893237
# 5106    40.000000
# 5107    30.600000
# 5108    25.600000
# 5109    26.200000
# Name: bmi, Length: 5110, dtype: float64

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# ...

# %%
del data['id']

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# ## Data visualization

# %%
plt.bar(data['hypertension'],data['stroke'],color=['r','b','g'])
plt.xlabel('hypertension')
plt.ylabel('stroke')
plt.title('stroke by hypertension')
# Out:
# Text(0.5, 1.0, 'stroke by hypertension')

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
sns.pairplot(data,hue="stroke",size=3)
plt.show()

# %%
plt.subplot(1,2,2)
sns.countplot(data['ever_married'], hue= data['stroke'])

# %%
sns.countplot(data['work_type'], hue= data['stroke'])

# %%
sns.countplot(data['smoking_status'], hue= data['stroke'])

# %% [markdown]
# # Data Preprocessing

# %%
X = data.drop(['stroke'],axis=1)
Y = data['stroke']

X_category = X.select_dtypes(include='object')
X_numeric = X.select_dtypes(exclude='object')

X = pd.concat([X_category, X_numeric], axis=1)

# %%
# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
imp_std = Pipeline(
    steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', StandardScaler()),
    ]
)

# %%
ct = ColumnTransformer(
    remainder='passthrough',
    transformers = [
        ("Encoding",OneHotEncoder(),[0,1,2,3,4]),
        ("Scaler", imp_std,[5,6,7,8,9])
    ]
)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20)

# %%
ct.fit(X_train)

X_train = ct.transform(X_train)
X_test = ct.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.        ,  1.        ,  0.        , ..., -0.23791548,
#          0.37105686,  1.17465437],
#        [ 0.        ,  1.        ,  0.        , ..., -0.23791548,
#          0.5939775 , -0.68684045],
#        [ 1.        ,  0.        ,  0.        , ..., -0.23791548,
#         -0.18193658,  2.86692239],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ..., -0.23791548,
#         -0.68941797, -1.06434639],
#        [ 1.        ,  0.        ,  0.        , ..., -0.23791548,
#         -0.52835835, -1.53297445],
#        [ 0.        ,  1.        ,  0.        , ..., -0.23791548,
#         -0.20911124, -1.0122766 ]])

# %% [markdown]
# #### Building a Machine Learning Algorithems

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=20)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[976  46]
#  [  0   0]]

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y_pred,y_test)

# %%
acc
# Out:
# 0.9549902152641878

# %% [markdown]
# ### Gaussian NB

# %%
model1=GaussianNB()

# %%
model1.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred1=model1.predict(X_test)

# %%
y_pred1
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
confusion_matrix(y_pred1,y_test)
# Out:
# array([[227,   0],
#        [749,  46]], dtype=int64)

# %%
acc1=accuracy_score(y_pred1,y_test)

# %%
acc1
# Out:
# 0.2671232876712329

# %% [markdown]
# #### SVC

# %%
svm=SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
pred=svm.predict(X_test)

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[976,  46],
#        [  0,   0]], dtype=int64)

# %%
accuracy=accuracy_score(pred,y_test)

# %%
accuracy
# Out:
# 0.9549902152641878

# %% [markdown]
# #### DECISION TREE

# %%
dt=DecisionTreeClassifier(criterion='entropy')

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
prediction=dt.predict(X_test)

# %%
confusion_matrix(prediction,y_test)
# Out:
# array([[940,  39],
#        [ 36,   7]], dtype=int64)

# %%
DT_accuracy=accuracy_score(prediction,y_test)

# %%
DT_accuracy
# Out:
# 0.9266144814090019

# %% [markdown]
# #### RANDOM FOREST

# %%
rm=RandomForestClassifier(n_estimators=5,criterion='entropy')

# %%
rm.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=5,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rm_prediction=rm.predict(X_test)

# %%
confusion_matrix(rm_prediction,y_test)
# Out:
# array([[960,  42],
#        [ 16,   4]], dtype=int64)

# %%
RM_accuracy=accuracy_score(rm_prediction,y_test)

# %%
RM_accuracy
# Out:
# 0.9432485322896281

# %% [markdown]
# #### LogisticRegression

# %%
log_reg=LogisticRegression()

# %%
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lg_prediction=log_reg.predict(X_test)

# %%
confusion_matrix(lg_prediction,y_test)
# Out:
# array([[976,  46],
#        [  0,   0]], dtype=int64)

# %%
LR_accuracy=accuracy_score(lg_prediction,y_test)

# %%
LR_accuracy
# Out:
# 0.9549902152641878

# %% [markdown]
# #### ADA BOOST CLASSIFIER

# %%
adb=AdaBoostClassifier()

# %%
adb.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)

# %%
adb_prediction=adb.predict(X_test)

# %%
confusion_matrix(adb_prediction,y_test)
# Out:
# array([[976,  46],
#        [  0,   0]], dtype=int64)

# %%
ADB_accuracy=accuracy_score(adb_prediction,y_test)

# %%
ADB_accuracy
# Out:
# 0.9549902152641878
